# %%
# conda install lightgbm

# %%
import random
import copy
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from sklearn import metrics
import tensorflow as tf
from scipy import stats
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix, precision_recall_curve, accuracy_score
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

import warnings
warnings.filterwarnings("ignore")
# Out:
# 2022-11-21 19:17:03.338947: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/pritish/anaconda3/envs/jami/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
df= pd.read_pickle('final_labelled_data.pkl')
df.head()
# Out:
#    TransactionAmt  ProductCD  card1  card2  card3  card5  card6  addr1  addr2  \
# 0            68.5          4   3417    500     42     38      1    166     65
# 1            29.0          4   7922    303     42      2      1    173     65
# 2            59.0          4   9383    389     42     58      2    178     65
# 3            50.0          4   6991    466     42     14      2    282     65
# 4            50.0          1   9262    413     42      2      1    241     65
#
#    dist1  ...  uid1_DT_M_ct  uid2_DT_M_ct  uid1_id_02_ct  uid2_id_02_ct  \
# 0   19.0  ...             1             1              0              0
# 1    NaN  ...             6             6              1              1
# 2  287.0  ...             4             4              0              0
# 3    NaN  ...             6             6              2              2
# 4    NaN  ...             1             1              1              1
#
#    uid1_V127_ct  uid2_V127_ct  uid1_V307_ct  uid2_V307_ct  outsider15  isFraud
# 0             1             1             1             1           1        0
# 1             4             4             1             1           0        0
# 2             2             2             2             2           1        0
# 3           114           114           115           115           0        0
# 4             1             1             1             1           0        0
#
# [5 rows x 297 columns]

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        return mis_val_table_ren_columns

# %%
def tpr_fpr_threshold_auc(Y, proba):
    
    '''
        Utility Function to return fpr, tpr, threshold and roc_auc.
    '''
    
    fpr, tpr, threshold = sklearn.metrics.roc_curve(Y, proba)
    roc_auc = metrics.auc(fpr, tpr)
    
    return (fpr, tpr, threshold, roc_auc)

# %%
def train_test_auc(train_fpr, train_tpr, train_roc_auc, cv_fpr, cv_tpr, cv_roc_auc):

    '''
        Utility Function to Draw ROC-AUC Curves for Train and Validation Datasets.
    '''
    
    plt.title('\nReceiver Operating Characteristic\n')
    plt.plot(train_fpr, train_tpr, label = 'Train AUC = %0.2f' % train_roc_auc)
    plt.plot(cv_fpr, cv_tpr, label = 'CV AUC = %0.2f' % cv_roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate (TPR)')
    plt.xlabel('False Positive Rate (FPR)')
    plt.show()

# %%
def best_threshold(threshold,tpr,fpr):
    
    '''
        Utility Function to return the best threshold value based on the TPR and FPR values.
    '''
    
    return threshold[np.argmax(tpr*(1-fpr))];


def class_label(best_thr, pred_score):
    
    '''
        Utility Function to return the class label based on the chosen threshold.
    '''
    return np.where(pred_score>best_thr,1,0);

# %%
def draw_confusion_matrix(Y, predicted):
    
    '''
        Utility Function to draw Confusion Matrix.
    '''

    cv_cm = confusion_matrix(Y, predicted)
    sns.heatmap(cv_cm, annot=True,fmt="d",cmap='Oranges', xticklabels=['Legit', 'Fraudulent'], yticklabels=['Legit', 'Fraudulent'])
    plt.title('\nConfusion  Matrix\n')
    plt.xlabel('True')
    plt.ylabel('Predicted')
    plt.show()

# %%
print("columns with null values: ")
print(list(df.columns[df.isnull().any()]))
print('===========================================')

missing_values = missing_values_table(df)
missing_values[:].style.background_gradient(cmap='Reds')
# Out:
# columns with null values:
# ['dist1', 'D6', 'D8', 'D9', 'D12', 'D13', 'D14', 'V1', 'V3', 'V4', 'V6', 'V8', 'V11', 'V13', 'V18', 'V20', 'V30', 'V36', 'V37', 'V40', 'V44', 'V47', 'V48', 'V52', 'V54', 'V59', 'V70', 'V76', 'V78', 'V80', 'V81', 'V82', 'V87', 'V91', 'V99', 'V127', 'V130', 'V131', 'V139', 'V147', 'V158', 'V165', 'V166', 'V169', 'V171', 'V173', 'V174', 'V175', 'V176', 'V180', 'V183', 'V185', 'V195', 'V198', 'V203', 'V205', 'V207', 'V209', 'V210', 'V215', 'V216', 'V220', 'V221', 'V223', 'V230', 'V234', 'V235', 'V238', 'V240', 'V241', 'V250', 'V252', 'V257', 'V258', 'V260', 'V262', 'V263', 'V264', 'V265', 'V268', 'V271', 'V274', 'V277', 'V282', 'V283', 'V289', 'V291', 'V303', 'V307', 'V310', 'V312', 'V314', 'V315', 'id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06', 'id_09', 'id_10', 'id_11', 'TransactionAmt_card1_std', 'TransactionAmt_card1_addr1_std', 'TransactionAmt_card1_addr1_P_emaildomain_std', 'D9_card1_mean', 'D9_card1_std', 'D9_card1_addr1_mean', 'D9_card1_addr1_std', 'D9_card1_addr1_P_emaildomain_mean', 'D9_card1_addr1_P_emaildomain_std', 'D11_card1_mean', 'D11_card1_std', 'D11_card1_addr1_mean', 'D11_card1_addr1_std', 'D11_card1_addr1_P_emaildomain_mean', 'D11_card1_addr1_P_emaildomain_std', 'TransactionAmt_uid1_std', 'TransactionAmt_uid2_std', 'D4_uid1_mean', 'D4_uid1_std', 'D4_uid2_mean', 'D4_uid2_std', 'D9_uid1_mean', 'D9_uid1_std', 'D9_uid2_mean', 'D9_uid2_std', 'D10_uid1_mean', 'D10_uid1_std', 'D10_uid2_mean', 'D10_uid2_std', 'D15_uid1_mean', 'D15_uid1_std', 'D15_uid2_mean', 'D15_uid2_std', 'C14_uid1_std', 'C14_uid2_std']
# ===========================================
# Your selected dataframe has 297 columns.
# There are 137 columns that have missing values.
# <style type="text/css">
# #T_2c0e3_row0_col0, #T_2c0e3_row0_col1, #T_2c0e3_row1_col0, #T_2c0e3_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2c0e3_row2_col0, #T_2c0e3_row2_col1 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_2c0e3_row3_col0, #T_2c0e3_row3_col1, #T_2c0e3_row4_col0, #T_2c0e3_row4_col1 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# #T_2c0e3_row5_col0, #T_2c0e3_row5_col1 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_2c0e3_row6_col0, #T_2c0e3_row6_col1, #T_2c0e3_row7_col0, #T_2c0e3_row7_col1, #T_2c0e3_row8_col0, #T_2c0e3_row8_col1, #T_2c0e3_row9_col0, #T_2c0e3_row9_col1 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_2c0e3_row10_col0, #T_2c0e3_row10_col1, #T_2c0e3_row11_col0, #T_2c0e3_row11_col1, #T_2c0e3_row12_col0, #T_2c0e3_row12_col1, #T_2c0e3_row13_col0, #T_2c0e3_row13_col1, #T_2c0e3_row14_col0, #T_2c0e3_row14_col1 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_2c0e3_row15_col0, #T_2c0e3_row15_col1, #T_2c0e3_row16_col0, #T_2c0e3_row16_col1, #T_2c0e3_row17_col0, #T_2c0e3_row17_col1, #T_2c0e3_row18_col0, #T_2c0e3_row18_col1, #T_2c0e3_row19_col0, #T_2c0e3_row19_col1, #T_2c0e3_row20_col0, #T_2c0e3_row20_col1, #T_2c0e3_row21_col0, #T_2c0e3_row21_col1, #T_2c0e3_row22_col0, #T_2c0e3_row22_col1, #T_2c0e3_row23_col0, #T_2c0e3_row23_col1, #T_2c0e3_row24_col0, #T_2c0e3_row24_col1, #T_2c0e3_row25_col0, #T_2c0e3_row25_col1, #T_2c0e3_row26_col0, #T_2c0e3_row26_col1, #T_2c0e3_row27_col0, #T_2c0e3_row27_col1, #T_2c0e3_row28_col0, #T_2c0e3_row28_col1, #T_2c0e3_row29_col0, #T_2c0e3_row29_col1, #T_2c0e3_row30_col0, #T_2c0e3_row30_col1 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_2c0e3_row31_col0, #T_2c0e3_row31_col1, #T_2c0e3_row32_col0, #T_2c0e3_row32_col1 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_2c0e3_row33_col0, #T_2c0e3_row33_col1, #T_2c0e3_row34_col0, #T_2c0e3_row34_col1, #T_2c0e3_row35_col0, #T_2c0e3_row35_col1, #T_2c0e3_row36_col0, #T_2c0e3_row36_col1, #T_2c0e3_row37_col0, #T_2c0e3_row37_col1, #T_2c0e3_row38_col0, #T_2c0e3_row38_col1, #T_2c0e3_row39_col0, #T_2c0e3_row39_col1, #T_2c0e3_row40_col0, #T_2c0e3_row40_col1, #T_2c0e3_row41_col0, #T_2c0e3_row41_col1, #T_2c0e3_row42_col0, #T_2c0e3_row42_col1, #T_2c0e3_row43_col0, #T_2c0e3_row43_col1, #T_2c0e3_row44_col0, #T_2c0e3_row44_col1, #T_2c0e3_row45_col0, #T_2c0e3_row45_col1, #T_2c0e3_row46_col0, #T_2c0e3_row46_col1, #T_2c0e3_row47_col0, #T_2c0e3_row47_col1, #T_2c0e3_row48_col0, #T_2c0e3_row48_col1, #T_2c0e3_row49_col0, #T_2c0e3_row49_col1, #T_2c0e3_row50_col0, #T_2c0e3_row50_col1 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_2c0e3_row51_col0, #T_2c0e3_row51_col1, #T_2c0e3_row52_col0, #T_2c0e3_row52_col1, #T_2c0e3_row53_col0, #T_2c0e3_row53_col1, #T_2c0e3_row54_col0, #T_2c0e3_row54_col1, #T_2c0e3_row55_col0, #T_2c0e3_row55_col1, #T_2c0e3_row56_col0, #T_2c0e3_row56_col1, #T_2c0e3_row57_col0, #T_2c0e3_row57_col1, #T_2c0e3_row58_col0, #T_2c0e3_row58_col1 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_2c0e3_row59_col0, #T_2c0e3_row59_col1 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_2c0e3_row60_col0, #T_2c0e3_row60_col1 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_2c0e3_row61_col0, #T_2c0e3_row61_col1 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_2c0e3_row62_col0, #T_2c0e3_row62_col1, #T_2c0e3_row63_col0, #T_2c0e3_row63_col1 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_2c0e3_row64_col0, #T_2c0e3_row64_col1 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_2c0e3_row65_col0, #T_2c0e3_row65_col1, #T_2c0e3_row66_col0, #T_2c0e3_row66_col1, #T_2c0e3_row67_col0, #T_2c0e3_row67_col1, #T_2c0e3_row68_col0, #T_2c0e3_row68_col1, #T_2c0e3_row69_col0, #T_2c0e3_row69_col1, #T_2c0e3_row70_col0, #T_2c0e3_row70_col1 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_2c0e3_row71_col0, #T_2c0e3_row71_col1, #T_2c0e3_row72_col0, #T_2c0e3_row72_col1 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_2c0e3_row73_col0, #T_2c0e3_row73_col1 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_2c0e3_row74_col0, #T_2c0e3_row74_col1, #T_2c0e3_row75_col0, #T_2c0e3_row75_col1, #T_2c0e3_row76_col0, #T_2c0e3_row76_col1, #T_2c0e3_row77_col0, #T_2c0e3_row77_col1, #T_2c0e3_row78_col0, #T_2c0e3_row78_col1, #T_2c0e3_row79_col0, #T_2c0e3_row79_col1, #T_2c0e3_row80_col0, #T_2c0e3_row80_col1 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_2c0e3_row81_col0, #T_2c0e3_row81_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_2c0e3_row82_col0, #T_2c0e3_row82_col1 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_2c0e3_row83_col0, #T_2c0e3_row83_col1 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_2c0e3_row84_col0, #T_2c0e3_row84_col1 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_2c0e3_row85_col0, #T_2c0e3_row85_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_2c0e3_row86_col0, #T_2c0e3_row86_col1 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_2c0e3_row87_col0, #T_2c0e3_row87_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_2c0e3_row88_col0, #T_2c0e3_row88_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_2c0e3_row89_col0, #T_2c0e3_row89_col1, #T_2c0e3_row90_col0, #T_2c0e3_row90_col1, #T_2c0e3_row91_col0, #T_2c0e3_row91_col1, #T_2c0e3_row92_col0, #T_2c0e3_row92_col1, #T_2c0e3_row93_col0, #T_2c0e3_row93_col1, #T_2c0e3_row94_col0, #T_2c0e3_row94_col1, #T_2c0e3_row95_col0, #T_2c0e3_row95_col1, #T_2c0e3_row96_col0, #T_2c0e3_row96_col1 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_2c0e3_row97_col0, #T_2c0e3_row97_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_2c0e3_row98_col0, #T_2c0e3_row98_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_2c0e3_row99_col0, #T_2c0e3_row99_col1, #T_2c0e3_row100_col0, #T_2c0e3_row100_col1, #T_2c0e3_row101_col0, #T_2c0e3_row101_col1, #T_2c0e3_row102_col0, #T_2c0e3_row102_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_2c0e3_row103_col0, #T_2c0e3_row103_col1, #T_2c0e3_row104_col0, #T_2c0e3_row104_col1, #T_2c0e3_row105_col0, #T_2c0e3_row105_col1, #T_2c0e3_row106_col0, #T_2c0e3_row106_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_2c0e3_row107_col0, #T_2c0e3_row108_col0, #T_2c0e3_row108_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_2c0e3_row107_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_2c0e3_row109_col0, #T_2c0e3_row109_col1, #T_2c0e3_row110_col0, #T_2c0e3_row110_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_2c0e3_row111_col0, #T_2c0e3_row111_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_2c0e3_row112_col0, #T_2c0e3_row112_col1, #T_2c0e3_row113_col0, #T_2c0e3_row113_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_2c0e3_row114_col0, #T_2c0e3_row114_col1, #T_2c0e3_row115_col0, #T_2c0e3_row115_col1, #T_2c0e3_row116_col0, #T_2c0e3_row116_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_2c0e3_row117_col0, #T_2c0e3_row117_col1, #T_2c0e3_row118_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_2c0e3_row118_col0, #T_2c0e3_row119_col0, #T_2c0e3_row119_col1, #T_2c0e3_row120_col0, #T_2c0e3_row120_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_2c0e3_row121_col0, #T_2c0e3_row121_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_2c0e3_row122_col0, #T_2c0e3_row122_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_2c0e3_row123_col0, #T_2c0e3_row123_col1, #T_2c0e3_row124_col0, #T_2c0e3_row124_col1, #T_2c0e3_row125_col0, #T_2c0e3_row125_col1, #T_2c0e3_row126_col0, #T_2c0e3_row126_col1, #T_2c0e3_row127_col0, #T_2c0e3_row127_col1, #T_2c0e3_row128_col0, #T_2c0e3_row128_col1, #T_2c0e3_row129_col0, #T_2c0e3_row129_col1, #T_2c0e3_row130_col0, #T_2c0e3_row130_col1, #T_2c0e3_row131_col0, #T_2c0e3_row131_col1, #T_2c0e3_row132_col0, #T_2c0e3_row132_col1, #T_2c0e3_row133_col0, #T_2c0e3_row133_col1, #T_2c0e3_row134_col0, #T_2c0e3_row134_col1, #T_2c0e3_row135_col0, #T_2c0e3_row135_col1, #T_2c0e3_row136_col0, #T_2c0e3_row136_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id

# %%
def normalize(X_train, X_test):
    '''
        Utility Function to scale the values of the Train, CV and Test Datasets between 0 and 1.
    '''
    
    for f in X_train.columns:

        min_val = X_train[f].min()
        max_val = X_train[f].max()
        
        X_train[f] = (X_train[f]-min_val)/(max_val-min_val)
        X_test[f] = (X_test[f]-min_val)/(max_val-min_val)
        
    return (X_train, X_test)

# %%
X = df.drop(['isFraud','uid1_P_emaildomain_ct', 'uid2_P_emaildomain_ct'], axis=1)
y = df['isFraud']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1, stratify=y)
del df
print('Train shape:',X_train.shape)
print('Test shape:',X_test.shape)
# Out:
# Train shape: (442903, 294)
# Test shape: (147635, 294)

# %%
X_test.isnull().any().sum()
# Out:
# 137

# %%
# Set1 (Imputed and Normalized)
X_train1 = X_train.fillna(-999)
X_test1 = X_test.fillna(-999)
X_train1, X_test1 = normalize(X_train1, X_test1)

# Set2 (Imputed)
X_train2 = X_train.fillna(-999)
X_test2 = X_test.fillna(-999)

# Set3 (Raw)
X_train3 = X_train
X_test3 = X_test

del X_train, X_test

# %%
train1 = X_train1
train1['isFraud'] = y_train

test1 = X_test1

del X_train1, X_test1



train2 = X_train2
train2['isFraud'] = y_train

test2 = X_test2

del X_train2, X_test2



train3 = X_train3
train3['isFraud'] = y_train

test3 = X_test3

del X_train3, y_train, X_test3

# %%
y_train = train1.pop('isFraud')
_ = train2.pop('isFraud')
_ = train3.pop('isFraud')


X_train1 = train1
X_test1 = test1 

X_train2 = train2
X_test2 = test2 

X_train3 = train3
X_test3 = test3 

del train1, train2, train3

# %%
print("*"*60)
print("\n Train Dataset Set1 Shape : {} \n".format(X_train1.shape))
print("\n Test Dataset Set1 Shape : {} \n".format(X_test1.shape))
print("*"*60)
print("\n Train Dataset Set1 Shape : {} \n".format(X_train1.shape))
print("\n Test Dataset Set2 Shape : {} \n".format(X_test2.shape))
print("*"*60)
print("\n Train Dataset Set1 Shape : {} \n".format(X_train1.shape))
print("\n Test Dataset Set3 Shape : {} \n".format(X_test3.shape))
print("*"*60)
# Out:
# ************************************************************
#
#  Train Dataset Set1 Shape : (442903, 294)
#
#
#  Test Dataset Set1 Shape : (147635, 294)
#
# ************************************************************
#
#  Train Dataset Set1 Shape : (442903, 294)
#
#
#  Test Dataset Set2 Shape : (147635, 294)
#
# ************************************************************
#
#  Train Dataset Set1 Shape : (442903, 294)
#
#
#  Test Dataset Set3 Shape : (147635, 294)
#
# ************************************************************

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(n_jobs = -1, class_weight = 'balanced', solver = 'saga', random_state = 3, max_iter=1000) 
lr.fit(X_train1, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, n_jobs=-1,
#                    random_state=3, solver='saga')

# %%
lr_train_proba = lr.predict_proba(X_train1)[:,1]
lr_test_proba = lr.predict_proba(X_test1)[:,1]

# %%
train_fpr, train_tpr, train_threshold, train_roc_auc = tpr_fpr_threshold_auc(y_train, lr_train_proba)
test_fpr, test_tpr, test_threshold, test_roc_auc = tpr_fpr_threshold_auc(y_test, lr_test_proba)

# %%
plt.rcParams["figure.figsize"] = (6, 5)
train_test_auc(train_fpr, train_tpr, train_roc_auc, test_fpr, test_tpr, test_roc_auc)

# %%
best_thr = best_threshold(test_threshold, test_tpr, test_fpr)
test_pred = class_label(best_thr, lr_test_proba)

draw_confusion_matrix(y_test, test_pred)

# %% [markdown]
# ###  Decision Tree

# %%
dt =  DecisionTreeClassifier(random_state=3, class_weight='balanced')
dt.fit(X_train2, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=3)

# %%
dt_train_proba = dt.predict_proba(X_train2)[:,1]
dt_test_proba = dt.predict_proba(X_test2)[:,1]

# %%
train_fpr, train_tpr, train_threshold, train_roc_auc = tpr_fpr_threshold_auc(y_train, dt_train_proba)
test_fpr, test_tpr, test_threshold, test_roc_auc = tpr_fpr_threshold_auc(y_test, dt_test_proba)

# %%
plt.rcParams["figure.figsize"] = (6, 5)
train_test_auc(train_fpr, train_tpr, train_roc_auc, test_fpr, test_tpr, test_roc_auc)

# %%
best_thr = best_threshold(test_threshold, test_tpr, test_fpr)
test_pred = class_label(best_thr, dt_test_proba)

draw_confusion_matrix(y_test, test_pred)

# %%
y_pred=dt.predict(X_test2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99    142469
#            1       0.59      0.58      0.59      5166
#
#     accuracy                           0.97    147635
#    macro avg       0.79      0.78      0.79    147635
# weighted avg       0.97      0.97      0.97    147635

# %% [markdown]
# ### Random Forest

# %%
rf =  RandomForestClassifier(n_jobs = -1, class_weight = 'balanced', random_state = 3)
rf.fit(X_train2, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=3)

# %%
rf_train_proba = rf.predict_proba(X_train2)[:,1]
rf_test_proba = rf.predict_proba(X_test2)[:,1]

# %%
train_fpr, train_tpr, train_threshold, train_roc_auc = tpr_fpr_threshold_auc(y_train, rf_train_proba)
test_fpr, test_tpr, test_threshold, test_roc_auc = tpr_fpr_threshold_auc(y_test, rf_test_proba)

# %%
plt.rcParams["figure.figsize"] = (6, 5)
train_test_auc(train_fpr, train_tpr, train_roc_auc, test_fpr, test_tpr, test_roc_auc)

# %%
best_thr = best_threshold(test_threshold, test_tpr, test_fpr)
test_pred = class_label(best_thr, rf_test_proba)

draw_confusion_matrix(y_test, test_pred)

# %%
y_pred=rf.predict(X_test2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    142469
#            1       0.96      0.55      0.70      5166
#
#     accuracy                           0.98    147635
#    macro avg       0.97      0.78      0.85    147635
# weighted avg       0.98      0.98      0.98    147635

# %% [markdown]
# ### XGBoost

# %%
weight = y_train.value_counts()[0]/y_train.value_counts()[1]

# %%
xgb =  XGBClassifier(scale_pos_weight = weight, objective='binary:logistic', eval_metric = 'auc', 
                         random_state = 3, tree_method = 'hist')
xgb.fit(X_train3, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=40,
#               num_parallel_tree=1, predictor='auto', random_state=3,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=27.579918693940762,
#               subsample=1, tree_method='hist', validate_parameters=1,
#               verbosity=None)

# %%
xgb1 =  XGBClassifier(scale_pos_weight = weight, objective='binary:logistic', eval_metric = 'auc', 
                         random_state = 3, tree_method = 'hist')
xgb1.fit(X_train1, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=40,
#               num_parallel_tree=1, predictor='auto', random_state=3,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=27.579918693940762,
#               subsample=1, tree_method='hist', validate_parameters=1,
#               verbosity=None)

# %%
xgb_train_proba = xgb.predict_proba(X_train3)[:,1]
xgb_test_proba = xgb.predict_proba(X_test3)[:,1]

# %%
xgb_train_proba1 = xgb1.predict_proba(X_train1)[:,1]
xgb_test_proba1 = xgb1.predict_proba(X_test1)[:,1]

# %%
train_fpr, train_tpr, train_threshold, train_roc_auc = tpr_fpr_threshold_auc(y_train, xgb_train_proba)
test_fpr, test_tpr, test_threshold, test_roc_auc = tpr_fpr_threshold_auc(y_test, xgb_test_proba)

# %%
train_fpr1, train_tpr1, train_threshold1, train_roc_auc1 = tpr_fpr_threshold_auc(y_train, xgb_train_proba1)
test_fpr1, test_tpr1, test_threshold1, test_roc_auc1 = tpr_fpr_threshold_auc(y_test, xgb_test_proba1)

# %%
plt.rcParams["figure.figsize"] = (6, 5)
train_test_auc(train_fpr, train_tpr, train_roc_auc, test_fpr, test_tpr, test_roc_auc)

# %%
plt.rcParams["figure.figsize"] = (6, 5)
train_test_auc(train_fpr1, train_tpr1, train_roc_auc1, test_fpr1, test_tpr1, test_roc_auc1)

# %%
best_thr = best_threshold(test_threshold, test_tpr, test_fpr)
test_pred = class_label(best_thr, xgb_test_proba)

draw_confusion_matrix(y_test, test_pred)

# %%
best_thr1 = best_threshold(test_threshold1, test_tpr1, test_fpr1)
test_pred1 = class_label(best_thr1, xgb_test_proba1)

draw_confusion_matrix(y_test, test_pred1)

# %%
y_pred=xgb.predict(X_test3)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97    142469
#            1       0.34      0.84      0.48      5166
#
#     accuracy                           0.94    147635
#    macro avg       0.67      0.89      0.72    147635
# weighted avg       0.97      0.94      0.95    147635

# %%
y_pred1=xgb.predict(X_test1)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98    142469
#            1       0.00      0.00      0.00      5166
#
#     accuracy                           0.97    147635
#    macro avg       0.48      0.50      0.49    147635
# weighted avg       0.93      0.97      0.95    147635

# %%
# save xgb model
saving_path_name = "./xgb_model"
saved_filepath = xgb.save_model(saving_path_name)
